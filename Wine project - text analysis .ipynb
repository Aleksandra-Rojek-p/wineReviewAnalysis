# %%
#load needed libraries
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline
from bs4 import BeautifulSoup
import re
import nltk
from nltk.corpus import stopwords # import stopwords list

#retrive cleaned dataset
# %store -r df
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87   20.0  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0                #NAME?                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1                #NAME?      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery  description_len points_range  \
# 0     White Blend              Nicosia              172      [85,90)
# 1  Portuguese Red  Quinta dos Avidagos              227      [85,90)
# 2      Pinot Gris            Rainstorm              186      [85,90)
# 3        Riesling           St. Julian              199      [85,90)
# 4      Pinot Noir         Sweet Cheeks              249      [85,90)
#
#   price_range  vintage
# 0     [20,40)     2013
# 1      [0,20)     2011
# 2      [0,20)     2013
# 3      [0,20)     2013
# 4    [60,100)     2012

# %%
from nltk.corpus import stopwords # import stopwords list

#Convert the stopwords to a set to fasten the process
stops = set(stopwords.words("english"))

def description_to_words (description):
    '''
    Function to convert a description to a string of words.
    The input is a single string (a raw description).
    The output is a single string (a preprocessed description).
    '''
    
    # 1. Remove HTML
    review_text = BeautifulSoup(description).get_text()
    
    # 2. Remove non-letters
    letters_only = re.sub("[^a-zA-Z]", " ", review_text)
        
    # 3. Convert to lower case & split into individual words
    words = letters_only.lower().split()
    
    # 4. Remove the stop words
    meaningful_words = [word for word in words if not word in stops]
    
    return(meaningful_words)

df["description_clean"] = df["description"].apply(description_to_words)
df["description_clean"].head()
# Out:
# 0    [aromas, include, tropical, fruit, broom, brim...
# 1    [ripe, fruity, wine, smooth, still, structured...
# 2    [tart, snappy, flavors, lime, flesh, rind, dom...
# 3    [pineapple, rind, lemon, pith, orange, blossom...
# 4    [much, like, regular, bottling, comes, across,...
# Name: description_clean, dtype: object

# %%
#Stemming
from nltk.stem.snowball import SnowballStemmer
ss = SnowballStemmer("english")

def stemming (text):
    '''
    Function performing stemming on the words.
    Input is a list of strings.
    The output is a list of stemmed words.
    '''
    stem_words = [ss.stem(word) for word in text]
    return(stem_words)

df["description_stem"] = df["description_clean"].apply(stemming)

# %%
#Lemmatizing
from nltk.tag import pos_tag
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

def lemmatizing (text):
    '''
    Function performing lemmatizing on the words.
    Input is a list of strings.
    The output is a list of lemmatized words.
    '''
    lemmatized = []
    
    for word, tag in pos_tag(text):
        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        lemmatized.append(lem.lemmatize(word, pos))
        
    return(lemmatized)

df["description_lem"] = df["description_clean"].apply(lemmatizing)

# %%
def get_binary (points):
    '''
    Function to get binary outcome.
    Input is number of points wine has.
    Output is 1 if wine is better than average, 0 if average or worse than average
    '''
    
    if points > df.points.mean():
        return(1)
    elif points <= df.points.mean():
        return(0)
    
df["better_than_avg"] = df["points"].apply(get_binary)

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['country', 'description', 'designation', 'province', 'region_1',
#        'region_2', 'taster_name', 'taster_twitter_handle', 'title', 'variety',
#        'winery', 'points_range', 'price_range', 'description_clean',
#        'description_stem'],
#       dtype='object')

# %%
def create_dummy_df(df, cat_cols, dummy_na):
    '''
    INPUT:
    df - pandas dataframe with categorical variables you want to dummy
    cat_cols - list of strings that are associated with names of the categorical columns
    dummy_na - Bool holding whether you want to dummy NA vals of categorical columns or not
    
    OUTPUT:
    df - a new dataframe that has the following characteristics:
            1. contains all columns that were not specified as categorical
            2. removes all the original columns in cat_cols
            3. dummy columns for each of the categorical columns in cat_cols
            4. if dummy_na is True - it also contains dummy columns for the NaN values
            5. Use a prefix of the column name with an underscore (_) for separating 
    '''
   
    for col in  cat_cols:
        try:
            # for each cat add dummy var, drop original column
            df = pd.concat([df.drop(col, axis=1), pd.get_dummies(df[col], prefix=col, prefix_sep='_', drop_first=True, dummy_na=dummy_na)], axis=1)
        except:
            continue
    return df

df_to_feed = df[["country", "variety", "price_range", "winery", "vintage", "description_len"]]
df_cat = create_dummy_df(df_to_feed, ["country", "variety", "price_range", "winery"], dummy_na = False)
df_cat.shape
# Out:
# (119928, 750)

# %%
#for some reason create_dummy_df didn't create a dummy column for winery - dropping winery
df_cat = df_cat.drop(["winery"], axis=1)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Prepare data for CountVectoriser
description_list = df["description_lem"].tolist()
cv_input = [" ".join(sublist) for sublist in description_list]

# Initialize the "CountVectorizer" object , sklearn bag of words tool.
vectorizer = CountVectorizer(analyzer = "word", 
                            ngram_range = (1,2),
                            max_features = 2000)

description_vectorized = vectorizer.fit_transform(cv_input)
# Out:
# ['abound',
#  'abundant',
#  'acacia',
#  'accent',
#  'accessible',
#  'accompany',
#  'acid',
#  'acidic',
#  'acidity',
#  'acidity balance',
#  'acidity crisp',
#  'acidity cut',
#  'acidity drink',
#  'acidity end',
#  'acidity finish',
#  'acidity firm',
#  'acidity flavor',
#  'acidity give',
#  'acidity keep',
#  'acidity make',
#  'acidity provide',
#  'acidity well',
#  'acidity wine',
#  'acre',
#  'across',
#  'across palate',
#  'add',
#  'add complexity',
#  'addition',
#  'additional',
#  'aftertaste',
#  'aftertaste drink',
#  'age',
#  'age drink',
#  'age month',
#  'age potential',
#  'age well',
#  'age wine',
#  'age year',
#  'aggressive',
#  'air',
#  'alcohol',
#  'allow',
#  'allspice',
#  'allure',
#  'almond',
#  'almost',
#  'almost sweet',
#  'along',
#  'alongside',
#  'alongside firm',
#  'already',
#  'also',
#  'also show',
#  'although',
#  'always',
#  'american',
#  'among',
#  'amount',
#  'ample',
#  'ample acidity',
#  'animal',
#  'anise',
#  'another',
#  'another year',
#  'ap',
#  'ap ritif',
#  'appeal',
#  'appear',
#  'appellation',
#  'appetizing',
#  'apple',
#  'apple citrus',
#  'apple flavor',
#  'apple fruit',
#  'apple lemon',
#  'apple peach',
#  'apple pear',
#  'apple skin',
#  'apple white',
#  'approach',
#  'approachable',
#  'apricot',
#  'apricot flavor',
#  'area',
#  'aroma',
#  'aroma blackberry',
#  'aroma flavor',
#  'aroma follow',
#  'aroma lead',
#  'aroma palate',
#  'aroma ripe',
#  'aromas',
#  'aromas black',
#  'aromas come',
#  'aromas flavor',
#  'aromas lead',
#  'aromas recall',
#  'aromas red',
#  'aromas ripe',
#  'aromas suggest',
#  'aromas white',
#  'aromatic',
#  'aromatic herb',
#  'aromatically',
#  'aromatics',
#  'around',
#  'array',
#  'asian',
#  'aspect',
#  'asphalt',
#  'assertive',
#  'astringency',
#  'astringent',
#  'astringent tannin',
#  'atop',
#  'attention',
#  'attractive',
#  'attractive acidity',
#  'attractive wine',
#  'attractively',
#  'austere',
#  'avola',
#  'away',
#  'back',
#  'backbone',
#  'backdrop',
#  'background',
#  'bacon',
#  'bake',
#  'bake apple',
#  'bake berry',
#  'bake plum',
#  'bake spice',
#  'baked',
#  'baking',
#  'baking spice',
#  'balance',
#  'balance acidity',
#  'balance wine',
#  'balanced',
#  'balanced wine',
#  'balsamic',
#  'balsamic note',
#  'banana',
#  'barbecue',
#  'barbera',
#  'barely',
#  'barnyard',
#  'barolo',
#  'barrel',
#  'barrel age',
#  'barrel ferment',
#  'barrel flavor',
#  'barrel sample',
#  'barrel spice',
#  'base',
#  'basic',
#  'bay',
#  'bay leaf',
#  'bean',
#  'beautiful',
#  'beautifully',
#  'become',
#  'beef',
#  'beer',
#  'begin',
#  'behind',
#  'bell',
#  'bell pepper',
#  'benefit',
#  'berry',
#  'berry aromas',
#  'berry cherry',
#  'berry flavor',
#  'berry fruit',
#  'berry plum',
#  'berry spice',
#  'best',
#  'beyond',
#  'big',
#  'big bold',
#  'bit',
#  'bite',
#  'bitter',
#  'bitter almond',
#  'bitter chocolate',
#  'bitterness',
#  'black',
#  'black berry',
#  'black cherry',
#  'black currant',
#  'black fruit',
#  'black licorice',
#  'black olive',
#  'black pepper',
#  'black plum',
#  'black raspberry',
#  'black skin',
#  'black tea',
#  'blackberry',
#  'blackberry black',
#  'blackberry blueberry',
#  'blackberry cassis',
#  'blackberry cherry',
#  'blackberry currant',
#  'blackberry flavor',
#  'blackberry fruit',
#  'blackberry jam',
#  'blackberry plum',
#  'blanc',
#  'blast',
#  'blend',
#  'blend cabernet',
#  'blend grenache',
#  'blend merlot',
#  'blend sangiovese',
#  'blend syrah',
#  'block',
#  'blossom',
#  'blue',
#  'blue flower',
#  'blue fruit',
#  'blueberry',
#  'boast',
#  'bodied',
#  'body',
#  'body palate',
#  'body red',
#  'body wine',
#  'bold',
#  'bone',
#  'bone dry',
#  'boost',
#  'bordeaux',
#  'bordeaux blend',
#  'bordeaux style',
#  'botrytis',
#  'bottle',
#  'bottle age',
#  'bottling',
#  'bouquet',
#  'box',
#  'boysenberry',
#  'br',
#  'brace',
#  'bramble',
#  'brambly',
#  'brand',
#  'brawny',
#  'bread',
#  'briary',
#  'bright',
#  'bright acidity',
#  'bright cherry',
#  'bright fruit',
#  'bright red',
#  'brighten',
#  'brightness',
#  'brim',
#  'bring',
#  'brings',
#  'briny',
#  'brisk',
#  'brisk acidity',
#  'broad',
#  'brood',
#  'brown',
#  'brown sugar',
#  'brunello',
#  'brut',
#  'bubble',
#  'bubbly',
#  'build',
#  'burn',
#  'burnt',
#  'burst',
#  'butter',
#  'butter toast',
#  'butterscotch',
#  'buttery',
#  'buy',
#  'cab',
#  'cab franc',
#  'cabernet',
#  'cabernet franc',
#  'cabernet sauvignon',
#  'cake',
#  'california',
#  'call',
#  'candied',
#  'candy',
#  'capture',
#  'caramel',
#  'caramelize',
#  'cardamom',
#  'carmen',
#  'carob',
#  'carry',
#  'carry palate',
#  'case',
#  'cassis',
#  'cassis flavor',
#  'cedar',
#  'cedar flavor',
#  'cellar',
#  'cellaring',
#  'center',
#  'center stage',
#  'central',
#  'certainly',
#  'ch',
#  'ch teau',
#  'chalk',
#  'chalky',
#  'champagne',
#  'char',
#  'character',
#  'character wine',
#  'characteristic',
#  'characterize',
#  'chard',
#  'chardonnay',
#  'charm',
#  'cheese',
#  'cherry',
#  'cherry aromas',
#  'cherry berry',
#  'cherry black',
#  'cherry blackberry',
#  'cherry blueberry',
#  'cherry candy',
#  'cherry cassis',
#  'cherry chocolate',
#  'cherry cola',
#  'cherry cranberry',
#  'cherry crush',
#  'cherry currant',
#  'cherry flavor',
#  'cherry fruit',
#  'cherry jam',
#  'cherry licorice',
#  'cherry note',
#  'cherry pie',
#  'cherry plum',
#  'cherry raspberry',
#  'cherry red',
#  'cherry spice',
#  'cherry strawberry',
#  'cherry vanilla',
#  'chewy',
#  'chewy tannin',
#  'chicken',
#  'chill',
#  'chocolate',
#  'chocolate flavor',
#  'chocolaty',
#  'choice',
#  'chop',
#  'chop herb',
#  'choppy',
#  'chunky',
#  'cigar',
#  'cigar box',
#  'cinnamon',
#  'cinnamon spice',
#  'cinsault',
#  'citric',
#  'citrus',
#  'citrus flavor',
#  'citrus fruit',
#  'citrus note',
#  'citrus peel',
#  'citrus zest',
#  'citrusy',
#  'class',
#  'classic',
#  'clean',
#  'clean finish',
#  'clear',
#  'cleave',
#  'climate',
#  'clone',
#  'close',
#  'clove',
#  'coast',
#  'coastal',
#  'coat',
#  'cocoa',
#  'coconut',
#  'coffee',
#  'coffee bean',
#  'cola',
#  'cola flavor',
#  'cold',
#  'color',
#  'color wine',
#  'combination',
#  'combine',
#  'come',
#  'come across',
#  'come together',
#  'compact',
#  'compel',
#  'complement',
#  'complete',
#  'completely',
#  'complex',
#  'complex flavor',
#  'complex wine',
#  'complexity',
#  'component',
#  'compose',
#  'compote',
#  'concentrate',
#  'concentrate wine',
#  'concentrated',
#  'concentrated wine',
#  'concentration',
#  'considerable',
#  'continue',
#  'contrast',
#  'control',
#  'conveys',
#  'cook',
#  'cool',
#  'cool climate',
#  'core',
#  'could',
#  'could age',
#  'county',
#  'couple',
#  'cover',
#  'cr',
#  'cracker',
#  'craft',
#  'cranberry',
#  'cream',
#  'creaminess',
#  'creamy',
#  'creamy texture',
#  'create',
#  'creek',
#  'crisp',
#  'crisp acidity',
#  'crisp apple',
#  'crisp clean',
#  'crisp finish',
#  'crisp wine',
#  'crisply',
#  'crispness',
#  'cru',
#  'crunchy',
#  'crush',
#  'crush raspberry',
#  'crush stone',
#  'crust',
#  'cure',
#  'cure meat',
#  'currant',
#  'currant flavor',
#  'currant fruit',
#  'custard',
#  'cut',
#  'cut grass',
#  'cuv',
#  'dance',
#  'dark',
#  'dark berry',
#  'dark cherry',
#  'dark chocolate',
#  'dark color',
#  'dark fruit',
#  'dark plum',
#  'dark skin',
#  'dark spice',
#  'dark tannin',
#  'darker',
#  'dash',
#  'date',
#  'day',
#  'de',
#  'deal',
#  'decade',
#  'decadent',
#  'decant',
#  'decent',
#  'deep',
#  'deeply',
#  'define',
#  'definitely',
#  'delicate',
#  'delicately',
#  'delicious',
#  'delicious wine',
#  'deliciously',
#  'delightful',
#  'deliver',
#  'delivers',
#  'dense',
#  'dense wine',
#  'densely',
#  'density',
#  'depth',
#  'depth flavor',
#  'designate',
#  'despite',
#  'dessert',
#  'dessert wine',
#  'detail',
#  'develop',
#  'develop well',
#  'di',
#  'different',
#  'difficult',
#  'dill',
#  'dilute',
#  'dimension',
#  'dimensional',
#  'dinner',
#  'direct',
#  'dish',
#  'display',
#  'distinct',
#  'distinctive',
#  'do',
#  'dole',
#  'dominant',
#  'dominate',
#  'douro',
#  'draw',
#  'dre',
#  'dried',
#  'drink',
#  'drink next',
#  'drink soon',
#  'drink well',
#  'drink wine',
#  'drinkable',
#  'drinking',
#  'drive',
#  'driven',
#  'drop',
#  'drunk',
#  'dry',
#  'dry apricot',
#  'dry black',
#  'dry cherry',
#  'dry core',
#  'dry crisp',
#  'dry finish',
#  'dry fruit',
#  'dry full',
#  'dry herb',
#  'dry herbs',
#  'dry palate',
#  'dry riesling',
#  'dry style',
#  'dry tannic',
#  'dry tannin',
#  'dry wine',
#  'dryness',
#  'due',
#  'dust',
#  'dusty',
#  'dusty tannin',
#  'early',
#  'earth',
#  'earthiness',
#  'earthy',
#  'earthy aroma',
#  'easily',
#  'easy',
#  'easy drink',
#  'easy drinking',
#  'easygoing',
#  'edge',
#  'edgy',
#  'effort',
#  'elderberry',
#  'elegance',
#  'elegant',
#  'elegant wine',
#  'elegantly',
#  'element',
#  'emerge',
#  'end',
#  'energy',
#  'enhance',
#  'enjoy',
#  'enjoy soon',
#  'enjoyable',
#  'enjoyment',
#  'enough',
#  'entice',
#  'entirely',
#  'entry',
#  'equal',
#  'equal part',
#  'equally',
#  'especially',
#  'espresso',
#  'essence',
#  'estate',
#  'estate vineyard',
#  'eucalyptus',
#  'even',
#  'ever',
#  'every',
#  'everyday',
#  'everything',
#  'evident',
#  'evolve',
#  'example',
#  'excellent',
#  'exhibit',
#  'exotic',
#  'exotic fruit',
#  'exotic spice',
#  'expect',
#  'experience',
#  'express',
#  'expression',
#  'expressive',
#  'extend',
#  'extra',
#  'extract',
#  'extraction',
#  'extreme',
#  'extremely',
#  'exuberant',
#  'fade',
#  'faint',
#  'fairly',
#  'fall',
#  'family',
#  'fan',
#  'far',
#  'fare',
#  'farm',
#  'fat',
#  'feature',
#  'feel',
#  'feeling',
#  'fennel',
#  'ferment',
#  'fermentation',
#  'fig',
#  'fill',
#  'final',
#  'find',
#  'fine',
#  'fine acidity',
#  'fine grain',
#  'fine tannin',
#  'fine wine',
#  'finely',
#  'finesse',
#  'finish',
#  'finish clean',
#  'finish drink',
#  'finish dry',
#  'finish long',
#  'finishing',
#  'firm',
#  'firm acidity',
#  'firm fine',
#  'firm palate',
#  'firm structure',
#  'firm tannin',
#  'firm tannins',
#  'firmly',
#  'firmly structure',
#  'first',
#  'fish',
#  'five',
#  'five year',
#  'flashy',
#  'flat',
#  'flavor',
#  'flavor accent',
#  'flavor acidity',
#  'flavor along',
#  'flavor apple',
#  'flavor balance',
#  'flavor berry',
#  'flavor black',
#  'flavor blackberry',
#  'flavor cherry',
#  'flavor citrus',
#  'flavor come',
#  'flavor dominate',
#  'flavor drink',
#  'flavor dry',
#  'flavor finish',
#  'flavor fresh',
#  'flavor full',
#  'flavor give',
#  'flavor good',
#  'flavor green',
#  'flavor hint',
#  'flavor lemon',
#  'flavor light',
#  'flavor like',
#  'flavor linger',
#  'flavor make',
#  'flavor palate',
#  'flavor plum',
#  'flavor profile',
#  'flavor raspberry',
#  'flavor red',
#  'flavor rich',
#  'flavor ripe',
#  'flavor show',
#  'flavor soft',
#  'flavor sweet',
#  'flavor touch',
#  'flavor well',
#  'flavor wine',
#  'flavor wrap',
#  'flavorful',
#  'flesh',
#  'fleshy',
#  'flint',
#  'flinty',
#  'floor',
#  'floral',
#  'floral aroma',
#  'floral note',
#  'flower',
#  'focus',
#  'focused',
#  'follow',
#  'food',
#  'food friendly',
#  'foot',
#  'force',
#  'forest',
#  'forest floor',
#  'form',
#  'forward',
#  'four',
#  'fragrance',
#  'fragrant',
#  'frame',
#  'framework',
#  'franc',
#  'franc merlot',
#  'franc petit',
#  'french',
#  'french oak',
#  'fresh',
#  'fresh acidity',
#  'fresh apple',
#  'fresh crisp',
#  'fresh fruit',
#  'fresh fruity',
#  'fresh herb',
#  'fresh wine',
#  'freshly',
#  'freshness',
#  'friendly',
#  'front',
#  'fruit',
#  'fruit acidity',
#  'fruit aroma',
#  'fruit aromas',
#  'fruit balance',
#  'fruit character',
#  'fruit citrus',
#  'fruit come',
#  'fruit drink',
#  'fruit dry',
#  'fruit finish',
#  'fruit flavor',
#  'fruit forward',
#  'fruit fresh',
#  'fruit give',
#  'fruit hint',
#  'fruit lead',
#  'fruit light',
#  'fruit note',
#  'fruit palate',
#  'fruit rich',
#  'fruit richness',
#  'fruit ripe',
#  'fruit show',
#  'fruit soft',
#  'fruit spice',
#  'fruit touch',
#  'fruit well',
#  'fruit wine',
#  'fruitiness',
#  'fruity',
#  'fruity wine',
#  'full',
#  'full body',
#  'full fruit',
#  'full mouth',
#  'full ripe',
#  'fully',
#  'fun',
#  'funky',
#  'future',
#  'gain',
#  'game',
#  'gamy',
#  'garnacha',
#  'generic',
#  'generous',
#  'gentle',
#  'gently',
#  'get',
#  'gew',
#  'gew rztraminer',
#  'ginger',
#  'give',
#  'give time',
#  'give way',
#  'give wine',
#  'give year',
#  'glass',
#  'go',
#  'gold',
#  'gold color',
#  'golden',
#  'good',
#  'good acidity',
#  'good balance',
#  'good wine',
#  'gooseberry',
#  'gorgeous',
#  'grabby',
#  'grace',
#  'grain',
#  'grain tannin',
#  'grainy',
#  'grand',
#  'granite',
#  'grape',
#  'grapefruit',
#  'grapefruit flavor',
#  'graphite',
#  'grass',
#  'grassy',
#  'great',
#  'green',
#  'green apple',
#  'green fruit',
#  'green herb',
#  'green plum',
#  'grenache',
#  'grenache syrah',
#  'grigio',
#  'grill',
#  'grill herb',
#  'grip',
#  'grippy',
#  'gris',
#  'gritty',
#  'ground',
#  'ground pepper',
#  'grow',
#  'grown',
#  'guava',
#  'half',
#  'hand',
#  'hard',
#  'harmonious',
#  'harvest',
#  'hay',
#  'hazelnut',
#  'heady',
#  'healthy',
#  'heart',
#  'hearty',
#  'heat',
#  'heavily',
#  'heavy',
#  'heft',
#  'help',
#  'herb',
#  'herb flavor',
#  'herbaceous',
#  'herbal',
#  'herbal berry',
#  'herbal flavor',
#  'herbal note',
#  'herbs',
#  'high',
#  'high acidity',
#  'high alcohol',
#  'high tone',
#  'highlight',
#  'highly',
#  'hill',
#  'hint',
#  'hit',
#  'hold',
#  'home',
#  'honey',
#  'honey flavor',
#  'honeydew',
#  'honeysuckle',
#  'hot',
#  'hour',
#  'house',
#  'however',
#  'hue',
#  'huge',
#  'ideal',
#  'immediate',
#  'immediately',
#  'import',
#  'impress',
#  'impression',
#  'impressive',
#  'impressive wine',
#  'impressively',
#  'improve',
#  'include',
#  'influence',
#  'informal',
#  'initial',
#  'initially',
#  'inky',
#  'instead',
#  'integrate',
#  'integrated',
#  'intense',
#  'intense acidity',
#  'intensely',
#  'intensity',
#  'interest',
#  'interesting',
#  'intrigue',
#  'intriguing',
#  'invite',
#  'iron',
#  'italian',
#  'italy',
#  'jam',
#  'jammy',
#  'jasmine',
#  'jelly',
#  'join',
#  'juice',
#  'juiciness',
#  'juicy',
#  'juicy acidity',
#  'juicy black',
#  'juicy fruit',
#  'juicy palate',
#  'juicy red',
#  'juicy wine',
#  'juniper',
#  'keep',
#  'key',
#  'kick',
#  'kind',
#  'kiss',
#  'kiwi',
#  'knit',
#  'know',
#  'la',
#  'label',
#  'lace',
#  'lack',
#  'laden',
#  'lamb',
#  'large',
#  'last',
#  'lasting',
#  'late',
#  'lavender',
#  'layer',
#  'lead',
#  'lead nose',
#  'lead way',
#  'leaf',
#  'leafy',
#  'lean',
#  'least',
#  'leather',
#  'leather tobacco',
#  'leathery',
#  'leave',
#  'lee',
#  'leesy',
#  'lemon',
#  'lemon flavor',
#  'lemon lime',
#  'lemon peel',
#  'lemon zest',
#  'lemongrass',
#  'lemony',
#  'lend',
#  'length',
#  'lengthy',
#  'less',
#  ...]

# %%
from sklearn.model_selection import train_test_split

y = np.array(df.better_than_avg)
X = sp.sparse.hstack([description_vectorized, df_cat.values.astype(float)],format = 'csr')
features_names = vectorizer.get_feature_names() + df_cat.columns.tolist()

# split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 40)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

#Instantiate a LinearRegression model with normalized data
lm_model = LinearRegression(normalize=True)
    
#Fit your model to the training data
lm_model.fit(X_train, y_train)
        
#Predict the response for the training data and the test data
y_test_preds = lm_model.predict(X_test) 
y_train_preds = lm_model.predict(X_train)
    
#Obtain an rsquared value for both the training and test data
test_score = r2_score(y_test, y_test_preds)
train_score = r2_score(y_train, y_train_preds)
    
print(test_score, train_score)
# Out:
# 0.5128444066297537 0.5387928010936389

# %%
from sklearn.ensemble import RandomForestClassifier

# Instantiate model with 1000 decision trees
rf = RandomForestClassifier(n_estimators = 1000, random_state = 40)

# Train the model on training data
rf.fit(X_train, y_train)

#Predict the response for the training data and the test data
y_test_preds = rf.predict(X_test) 
y_train_preds = rf.predict(X_train)

#Obtain an rsquared value for both the training and test data
test_score = r2_score(y_test, y_test_preds)
train_score = r2_score(y_train, y_train_preds)

print(test_score, train_score)

# %%
#can we predict if wine will be better or worse than the average based on 
#the grape, the vintage and the description length?

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

X = df.drop(["description", "winery", "designation", "points", "province", 
             "region_1", "region_2", "title", "description_processed"], axis = 1)
y = df['points']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .30, random_state=42)

# %%
df.drop(["description", "winery" "designation", "points", "province", "region_1", "region_2", "title", "description_processed"], axis = 1)
df.drop(["winery"], axis = 1)
# Out:
#                                              description  \
# 0      This tremendous 100% varietal wine hails from ...
# 1      Ripe aromas of fig, blackberry and cassis are ...
# 2      Mac Watson honors the memory of a wine once ma...
# 3      This spent 20 months in 30% new French oak, an...
# 4      This is the top wine from La Bégude, named aft...
# ...                                                  ...
# 93071  Notes of honeysuckle and cantaloupe sweeten th...
# 93072  Citation is given as much as a decade of bottl...
# 93073  Well-drained gravel soil gives this wine its c...
# 93074  A dry style of Pinot Gris, this is crisp with ...
# 93075  Big, rich and off-dry, this is powered by inte...
#
#                                   designation  points  price        province  \
# 0                           Martha's Vineyard      96  235.0      California
# 1        Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2               Special Selected Late Harvest      96   90.0      California
# 3                                     Reserve      96   65.0          Oregon
# 4                                  La Brûlade      95   66.0        Provence
# ...                                       ...     ...    ...             ...
# 93071  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0           Mosel
# 93072                                     NaN      90   75.0          Oregon
# 93073                                   Kritt      90   30.0          Alsace
# 93074                                     NaN      90   32.0          Alsace
# 93075           Lieu-dit Harth Cuvée Caroline      90   21.0          Alsace
#
#                 region_1           region_2  \
# 0            Napa Valley               Napa
# 1                   Toro                NaN
# 2         Knights Valley             Sonoma
# 3      Willamette Valley  Willamette Valley
# 4                 Bandol                NaN
# ...                  ...                ...
# 93071                NaN                NaN
# 93072             Oregon       Oregon Other
# 93073             Alsace                NaN
# 93074             Alsace                NaN
# 93075             Alsace                NaN
#
#                                                    title  description_len  \
# 0                                                      0              355
# 1                                                      0              318
# 2                                                      0              280
# 3                                                      0              386
# 4                                                      0              376
# ...                                                  ...              ...
# 93071  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...              227
# 93072                  Citation 2004 Pinot Noir (Oregon)              233
# 93073  Domaine Gresser 2013 Kritt Gewurztraminer (Als...              225
# 93074      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)              216
# 93075  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...              169
#
#        vintage  ... variety_Çalkarası  variety_Žilavka  points_range_[85,90)  \
# 0         2013  ...                 0                0                     0
# 1         2013  ...                 0                0                     0
# 2         2013  ...                 0                0                     0
# 3         2013  ...                 0                0                     0
# 4         2013  ...                 0                0                     0
# ...        ...  ...               ...              ...                   ...
# 93071     2013  ...                 0                0                     0
# 93072     2004  ...                 0                0                     0
# 93073     2013  ...                 0                0                     0
# 93074     2012  ...                 0                0                     0
# 93075     2012  ...                 0                0                     0
#
#        points_range_[90,95)  points_range_[95,100]  price_range_[100,500)  \
# 0                         0                      1                      1
# 1                         0                      1                      1
# 2                         0                      1                      0
# 3                         0                      1                      0
# 4                         0                      1                      0
# ...                     ...                    ...                    ...
# 93071                     1                      0                      0
# 93072                     1                      0                      0
# 93073                     1                      0                      0
# 93074                     1                      0                      0
# 93075                     1                      0                      0
#
#        price_range_[20,40)  price_range_[40,60)  price_range_[500+]  \
# 0                        0                    0                   0
# 1                        0                    0                   0
# 2                        0                    0                   0
# 3                        0                    0                   0
# 4                        0                    0                   0
# ...                    ...                  ...                 ...
# 93071                    1                    0                   0
# 93072                    0                    0                   0
# 93073                    1                    0                   0
# 93074                    1                    0                   0
# 93075                    1                    0                   0
#
#        price_range_[60,100)
# 0                         0
# 1                         0
# 2                         1
# 3                         1
# 4                         1
# ...                     ...
# 93071                     0
# 93072                     1
# 93073                     0
# 93074                     0
# 93075                     0
#
# [93022 rows x 713 columns]

# %%
#Instantiate a LinearRegression model with normalized data
lm_model = LinearRegression(normalize=True)
    
#Fit your model to the training data
lm_model.fit(X_train, y_train)
        
#Predict the response for the training data and the test data
y_test_preds = lm_model.predict(X_test) 
y_train_preds = lm_model.predict(X_train)
    
#Obtain an rsquared value for both the training and test data
test_score = r2_score(y_test, y_test_preds)
train_score = r2_score(y_train, y_train_preds)
    
print(test_score, train_score)
# Out:
# -1.0965497393212993e+26 0.8635667439855326
